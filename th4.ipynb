# %%
def tong(n):
    a=0
    for i in range(1,n+1):    #W4A1
        a+=i
    print(a)
n=int(input())
tong(n)
# Out:
# 45

# %%
#W4A2
def nt(n):
    if n<=2:
        return False
    else:
        for i in range(2,int(n**0.5)+1):   
            if n%i==0:
                return False
        return True
n=int(input())
while n<=0:
    n=int(input())
if nt(n):
    print(n,'là số nguyến tố')
else:
    print(n,'không là số nguyên tố')
# Out:
# 9 không là số nguyên tố

# %%
def gt(n):
    a=1
    for i in range(1,n+1):   #W4A3
        a*=i
    print(a)
n=int(input())
gt(n)
# Out:
# 3628800

# %%
n=int(input())
n=abs(n)
dcs=0
while n>0:
    dcs=dcs+1 #W4A4
    n=n//10
print(dcs)
# Out:
# 3

# %%
n=int(input())#W4A5
m=input()
s=m.split()
if "42" in a:
        print('Ive found the meaning of life!')
else:
        print('it a joke')
# Out:
# it a joke

# %%
def nt(n):
    if n<2:
        return False
    else:
        for i in range(2,int(n**0.5)+1): #W4A6
            if n%i==0:
                return False
        return True
def khoang(a,b):
    m=0
    for i in range(a+1,b):
        if nt(i):
            m=m+i
    print(m)
a, b = map(int, input().split())
khoang(a,b)
# Out:
# 533

# %%
def daonguoc(n):
    dn=int(str(n)[::-1])
    return dn
n=int(input())
count=0
tong=n                        #W4A8
while tong!=daonguoc(tong):
    count+=1
    tong+=daonguoc(tong)
print(count,tong)
# Out:
# 24 8813200023188

# %%
def cp(n):
    for i in range(1,n+1):
        if i**2<=n:
            print(i**2,end=" ") #W4A9
cp(int(input()))
# Out:
# 1 4 9 16 25 36 49 64 81 100 121 144 169 196 225 256 289 324 361 400 441 484 529 576 625 676 729 784 841 900 961 1024 1089 1156 1225 1296 1369 1444 1521 1600 1681 1764 1849 1936 2025 2116 2209 2304

# %%
def nt(n):
    if n<2:
        return False
    else:
        for i in range(2,int(n**0.5)+1): #W4A7
            if n%i==0:
                return False
        return True
b=[]
n=int(input())
for a in range(1,n+1):
    if n%a==0 and nt(a):
        b.append(a)
print(max(b))
# Out:
# 5

# %%
def cl(n):
    a=[]
    while n!=1:
        if n%2==0:
            n=n/2
            a.append(n)
        else:
            n=n*3+1
            a.append(n)
    return len(a)+1
m=int(input())
count=0
c=0
for i in range(1,m+1):
    if cl(i)>count:
        count=cl(i)
        c=i
    elif cl(i)==count:
        c=c*1
print(c,count)
#W4A10
# Out:
# 6 9

# %%
n=int(input())
count=0
for i in range(1,n+1):
    if n%i==0 and i%2==0:
        count+=1
print(count)
#W4A11
# Out:
# 0

# %%
sotien=int(input())
thang=int(input())
print(int(sotien*(1+0.007)**thang))
#W4A12
# Out:
# 1087

# %%
def tonguoc(n):
    count=0
    for i in range(1,n):
        if n%i==0:
            count+=i
    return count
a,b=map(int,input().split())
if tonguoc(a)==b and tonguoc(b)==a:
    print('True')
else:
    print('False')
#W4A13
# Out:
# True

# %%
def uoc(n):
    a=[]
    for i in range(1,n+1):
        if n%i==0:
            a.append(i)
    return a
a,b=map(int,input().split())
count=0
if a>b:
    for k in uoc(b):
        if a%k==0:
            count=k
elif a==b:
    print(a)
else:
    for k in uoc(b):
        if a%k==0:
            count=k
print(count)
#W4A14
# Out:
# 1

# %%
tsc = int(input())
tsch = int(input())
found = False
for c in range(0, tsc + 1):
    if (tsch - c * 4) / 2 == tsc - c:
        print(c, tsc - c)
        found = True
        break
if not found:
    print("invalid")
#W4A15
# Out:
# 14 22

# %%
for i in range(1,100):
    if i%6==0:
        print(i,end=' ')
        #W4A16
# Out:
# 6 12 18 24 30 36 42 48 54 60 66 72 78 84 90 96

# %%
a=int(input())
for i in range(1,11):
    print('a x '+str(i)+' =',a*i)
    #W4A17
# Out:
# a x 1 = 8
# a x 2 = 16
# a x 3 = 24
# a x 4 = 32
# a x 5 = 40
# a x 6 = 48
# a x 7 = 56
# a x 8 = 64
# a x 9 = 72
# a x 10 = 80

# %%
n=int(int(inpuT()))
for i in range(1,n+1):
    if i%2==0:
        print(i)
        #W4A19
# Out:
# 1 3

# %%
n=int(input())
if n&(n-1)==0:
    print(n,'là có dạng 2^k')
else:
    print(n,'không có dạng 2^k')
    #W4A20
# Out:
# 8 là có dạng 2^k

# %%
n=int(int(input()))
tong=0
while n!=0:
    tong+=n%10
    n=n//10
print(tong)
#W4A21
# Out:
# 7

# %%
n=int(input())
chan=0
le=0
while n!=0:
    if n%2==0:
        chan+=1
        n=n//10
    else:
        le=+1
        n=n//10
if n%2==0:
    chan+=1
else:
    le+=1
print(chan,le)
#W4A22
# Out:
# 2 1

# %%
n=int(input())
s=0
a=0
for i in range(1,n+1):
    if s+i>=n:
        print(i)
        break
    else:
        s+=i
print(s)
#WA23
# Out:
# 10
# 45

# %%
A=float(input())
count=0
a=1
while count<=A:
    a+=1
    count+=1/a
print(a)
#24
# Out:
# 227

# %%
a=[]
x=int(input())
while x!=-1:
    a.append(x)
    x=int(int(input()))
print(max(a),min(a))
#25
# Out:
# 9 6

# %%
A = int(input())
f1, f2 = 1, 1
if A < 1:
    print(0)
else:
    while f2 <= A:
        f1, f2 = f2, f1 + f2
    print(f1)
    #26
# Out:
# 8

# %%
s = input()
count = 0
i = 0
n = 0
for _ in s:
    n += 1
for i in range(n):
    if s[i] != ' ':
        if i == 0 or s[i - 1] == ' ':
            count += 1
print(count)
#27

# %%
s = input()
first_word = ""
start = False
n = 0
for _ in s:
    n += 1
for i in range(n):
    if not start:
        if s[i] != ' ':
            start = True
            first_word += s[i]
    else:
        if s[i] == ' ':
            break
        first_word += s[i]
print(first_word)
#28

# %%
a,b,c=map(int,input().split(','))
print(a+b+c)
#29
# Out:
# 22

# %%
a=list(input().split())
inthuong=0
inhoa=0
so=0
for i in range(len(a)):
    if 48<=ord(a[i])<=57:
        so+=1
    elif 97<=ord(a[i])<=122:
        inthuong+=1
    elif 65<=ord(a[i])<=90:
        inhoa+=1
print(so,'so',inthuong,'in thuong',inhoa,'inhoa')
#30
# Out:
# 1 so 2 in thuong 0 inhoa

# %%
a=list(input().split())
tong=0
for i in range(len(a)):
    if 48<=ord(a[i])<=57:
        tong+=i
print(tong)
#31
# Out:
# 90

# %%
a=list(input().split())
m=0
b=0
c=0
d=0
for i in range(len(a)):
    if 48<=ord(a[i])<=57:
        m+=1
    elif 97<=ord(a[i])<=122:
        b+=1
    elif 65<=ord(a[i])<=90:
        c+=1
    else:
        d+=1
if m>=1 and b>=1 and c>=1 and d>=1 and len(a)>=6:
    print('mk manh')
else:
    print('mk yếu')
    #32
# Out:
# mk manh

# %%
n = int(input("Nhập số: "))
s = str(n)
parts = []
while len(s) > 3:
    parts.insert(0, s[-3:])  
    s = s[:-3]                
parts.insert(0, s)           
result = ".".join(parts)
print("Đổi sang chuỗi rồi in ra:", result)
#33

# %%
a = input("Nhập chuỗi a: ")
b = input("Nhập chuỗi b: ")
pos = a.find(b)
if pos != -1:
    a = a[:pos] + a[pos+len(b):]
print("Sau khi xóa, chuỗi a:", a)
#34
